# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv("./combined_race_results.csv",header=0)

# df2 = df[(df['DriverId'] == 'max_verstappen') | (df['DriverId'] == 'perez') | (df['DriverId'] == 'hamilton')]

# # Plot the line chart with a line for each driver
# plt.figure(figsize=(12, 8))  # Set the figure size
# for driver, group in df2.groupby('DriverId'):
#     plt.plot(group['Race_name'] , group['Points'], label=driver, marker='o')

# plt.xlabel('Race Name')
# plt.ylabel('Points')
# plt.title('Race Points by Driver')
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
# plt.yticks(group['Points'])
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place legend outside the plot
# plt.tight_layout()
# plt.show()
