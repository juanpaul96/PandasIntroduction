# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
race_results_df = pd.read_csv('./combined_race_results.csv')
desc_points_df = race_results_df.describe()['Points']
desc_points_df

race_results_df.head()
# Out:
#    Position PositionText  Points        DriverId GivenName  FamilyName  Race  \
# 0         1            1      25  max_verstappen       Max  Verstappen   1.0
# 1         1            1      25  max_verstappen       Max  Verstappen   1.0
# 2         1            1      25  max_verstappen       Max  Verstappen   NaN
# 3         1            1      25  max_verstappen       Max  Verstappen   NaN
# 4         2            2      18           perez    Sergio       Pérez   1.0
#
#             Race_name
# 0  Bahrain Grand Prix
# 1  Bahrain Grand Prix
# 2  Bahrain Grand Prix
# 3  Bahrain Grand Prix
# 4  Bahrain Grand Prix
